# %%
import csv

file = open("data/all_caseIDs.csv", "r")
data = list(csv.reader(file))

# %%
data = data[1:]

# %%
data
# Out:
# [['57f372ac-bbb2-4135-b4de-1e04e5aa24ec'],
#  ['6a518a32-5125-44a9-8200-a994943e71f0'],
#  ['752b588b-c175-4fba-b05e-6a8b57e56d3e'],
#  ['81fd4359-c34e-4124-880b-f51ee8ce497b'],
#  ['87807781-a709-4fe3-aee1-3d4261dcc720'],
#  ['9d22fcca-1032-4084-a712-2b9c8537ec39'],
#  ['9fb1d289-e4e4-4242-a19f-c5a9312f53ff'],
#  ['2a046e88-4805-4dba-9e03-3fabc661dd30'],
#  ['399d5ff6-7947-4108-a538-fb803e707ff9'],
#  ['68bb1d73-f130-419b-bb7e-ed223b50ae06'],
#  ['bec04289-6290-4f46-9f15-614a12840b0f'],
#  ['c90b8637-a80b-43c2-82f8-4d47bf9cb298'],
#  ['ce951171-ea6e-4f1d-b524-8ce120e2ec10'],
#  ['b11c95e1-dfca-43bd-b22d-4c305c662827'],
#  ['bfdd880f-9269-4799-ad81-cbee0e92d06e'],
#  ['d302144b-8344-4d20-9d99-d39b571d0f18'],
#  ['4a296447-475e-4b21-9301-2630bc221244'],
#  ['5b79f1b6-022c-4d51-bd78-5077d25c080c'],
#  ['11a9f6eb-f60e-4890-9e86-fbe3083979d1'],
#  ['762cddff-49ac-4396-b754-fa4b624ba314'],
#  ['145cd113-684f-424b-b97a-36ff7feb52e4'],
#  ['1bb63bf1-03f6-45e5-b568-ee6a4e8f6195'],
# ...

# %%
type(data)
# Out:
# list

# %%
url_start = "https://albanyny-energovpub.tylerhost.net/Apps/SelfService#/code/"

# %%
allurls = [f"{url_start}{d}" for d in data]
allurls
# Out:
# ["https://albanyny-energovpub.tylerhost.net/Apps/SelfService#/code/['57f372ac-bbb2-4135-b4de-1e04e5aa24ec']",
#  "https://albanyny-energovpub.tylerhost.net/Apps/SelfService#/code/['6a518a32-5125-44a9-8200-a994943e71f0']",
#  "https://albanyny-energovpub.tylerhost.net/Apps/SelfService#/code/['752b588b-c175-4fba-b05e-6a8b57e56d3e']",
#  "https://albanyny-energovpub.tylerhost.net/Apps/SelfService#/code/['81fd4359-c34e-4124-880b-f51ee8ce497b']",
#  "https://albanyny-energovpub.tylerhost.net/Apps/SelfService#/code/['87807781-a709-4fe3-aee1-3d4261dcc720']",
#  "https://albanyny-energovpub.tylerhost.net/Apps/SelfService#/code/['9d22fcca-1032-4084-a712-2b9c8537ec39']",
#  "https://albanyny-energovpub.tylerhost.net/Apps/SelfService#/code/['9fb1d289-e4e4-4242-a19f-c5a9312f53ff']",
#  "https://albanyny-energovpub.tylerhost.net/Apps/SelfService#/code/['2a046e88-4805-4dba-9e03-3fabc661dd30']",
# ...

# %%
import pandas as pd

# %%
df = pd.DataFrame(allurls)
df
# Out:
#                                                       0
# 0     https://albanyny-energovpub.tylerhost.net/Apps...
# 1     https://albanyny-energovpub.tylerhost.net/Apps...
# 2     https://albanyny-energovpub.tylerhost.net/Apps...
# 3     https://albanyny-energovpub.tylerhost.net/Apps...
# 4     https://albanyny-energovpub.tylerhost.net/Apps...
# ...                                                 ...
# 1629  https://albanyny-energovpub.tylerhost.net/Apps...
# 1630  https://albanyny-energovpub.tylerhost.net/Apps...
# 1631  https://albanyny-energovpub.tylerhost.net/Apps...
# 1632  https://albanyny-energovpub.tylerhost.net/Apps...
# 1633  https://albanyny-energovpub.tylerhost.net/Apps...
#
# [1634 rows x 1 columns]

# %%
df.to_csv('data/all_UnsafeandUnfitURLS.csv', index=False)
